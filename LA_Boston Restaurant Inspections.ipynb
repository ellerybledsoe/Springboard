# %%
import pandas as pd
import numpy as np
import json

# %%
inspections = pd.read_csv('/Users/EBled1/Springboard DS/Springboard/Capstone Two/Capstone Two/data/raw/inspections.csv')

# %%
inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191371 entries, 0 to 191370
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   activity_date        191371 non-null  object
#  1   employee_id          191371 non-null  object
#  2   facility_address     191371 non-null  object
#  3   facility_city        191371 non-null  object
#  4   facility_id          191371 non-null  object
#  5   facility_name        191371 non-null  object
#  6   facility_state       191371 non-null  object
#  7   facility_zip         191371 non-null  object
#  8   grade                191371 non-null  object
#  9   owner_id             191371 non-null  object
#  10  owner_name           191371 non-null  object
#  11  pe_description       191371 non-null  object
#  12  program_element_pe   191371 non-null  int64
#  13  program_name         190969 non-null  object
#  14  program_status       191371 non-null  object
# ...

# %%
inspections.head()
# Out:
#   activity_date employee_id          facility_address  facility_city  \
# 0    2017-05-09   EE0000593       17660 CHATSWORTH ST  GRANADA HILLS
# 1    2017-04-10   EE0000126    3615 PACIFIC COAST HWY       TORRANCE
# 2    2017-04-04   EE0000593       17515 CHATSWORTH ST  GRANADA HILLS
# 3    2017-08-15   EE0000971  44455 VALLEY CENTRAL WAY      LANCASTER
# 4    2016-09-26   EE0000145            11700 SOUTH ST        ARTESIA
#
#   facility_id               facility_name facility_state facility_zip grade  \
# 0   FA0175397  HOVIK'S FAMOUS MEAT & DELI             CA        91344     A
# 1   FA0242138              SHAKEY'S PIZZA             CA        90505     A
# 2   FA0007801              BAITH AL HALAL             CA        91344     A
# 3   FA0013858            FOOD 4 LESS #306             CA        93536     A
# 4   FA0179671           PHO LITTLE SAIGON             CA        90701     A
#
#     owner_id                      owner_name  \
# ...

# %%
#print(inspections.program_name.nunique())
#inspections.program_name.value_counts(normalize=True)

# %%
inspections.nunique()
# Out:
# activity_date             742
# employee_id               250
# facility_address        39283
# facility_city             181
# facility_id             44031
# facility_name           36627
# facility_state              3
# facility_zip             3037
# grade                       4
# owner_id                35713
# owner_name              34708
# pe_description             18
# program_element_pe         18
# program_name            38988
# program_status              2
# record_id               47445
# score                      45
# serial_number          191371
# service_code                2
# service_description         2
# dtype: int64

# %%
# reading in yelp data
# no California data in this version
yelp_business = pd.read_json('/Users/EBled1/Springboard DS/Springboard/Capstone Two/Capstone Two/data/raw/yelp_academic_dataset_business.json', lines=True)

# %%
yelp_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160585 entries, 0 to 160584
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   160585 non-null  object
#  1   name          160585 non-null  object
#  2   address       160585 non-null  object
#  3   city          160585 non-null  object
#  4   state         160585 non-null  object
#  5   postal_code   160585 non-null  object
#  6   latitude      160585 non-null  float64
#  7   longitude     160585 non-null  float64
#  8   stars         160585 non-null  float64
#  9   review_count  160585 non-null  int64
#  10  is_open       160585 non-null  int64
#  11  attributes    145593 non-null  object
#  12  categories    160470 non-null  object
#  13  hours         133244 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 17.2+ MB

# %%
yelp_business.head()
# Out:
#               business_id                     name              address  \
# 0  6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom         921 Pearl St
# 1  tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 2  bvN78flM8NLprQ1a1y5dRg           The Reclaimory   4720 Hawthorne Ave
# 3  oaepsyvc0J17qwi8cfrOWg              Great Clips   2566 Enterprise Rd
# 4  PE9uqAjdw0E4-8mjGl3wVA        Crossfit Terminus  1046 Memorial Dr SE
#
#           city state postal_code   latitude   longitude  stars  review_count  \
# 0      Boulder    CO       80302  40.017544 -105.283348    4.0            86
# 1     Portland    OR       97218  45.588906 -122.593331    4.0           126
# 2     Portland    OR       97214  45.511907 -122.613693    4.5            13
# 3  Orange City    FL       32763  28.914482  -81.295979    3.0             8
# 4      Atlanta    GA       30316  33.747027  -84.353424    4.0            14
#
#    is_open                                         attributes  \
# ...

# %%
# determining best fields to join on/filter criteria to reduce yelp data
print(inspections.facility_zip.nunique())
la_rest_zips = [inspections.facility_zip.unique()]
inspections.facility_zip.value_counts(normalize=True)
# Out:
# 3037
# 90012         0.011031
# 90045         0.010655
# 91748         0.010508
# 90028         0.010096
# 90015         0.008727
#                 ...
# 90504-1406    0.000005
# 90028-6144    0.000005
# 90744-3412    0.000005
# 90723-3669    0.000005
# 90520         0.000005
# Name: facility_zip, Length: 3037, dtype: float64

# %%
la_rest_zips[0:5]
# Out:
# [array(['91344', '90505', '93536', ..., '90001-1644', '90058-1028',
#         '91606-5020'], dtype=object)]

# %%
yelp_business.state.value_counts()
# Out:
# MA     36012
# OR     25175
# TX     24485
# FL     21907
# GA     18090
# BC     17298
# OH     11258
# CO      3198
# WA      3121
# CA        13
# NH         4
# ON         2
# AZ         2
# VA         2
# NY         2
# KY         1
# WY         1
# NM         1
# IL         1
# NC         1
# KS         1
# DE         1
# WI         1
# ABE        1
# DC         1
# OK         1
# HI         1
# AL         1
# MI         1
# ME         1
# MN         1
# Name: state, dtype: int64

# %%
print(len(yelp_business.loc[yelp_business.state == 'CA']))
print(len(yelp_business.loc[yelp_business.postal_code == '90012']))
print(len(yelp_business.loc[yelp_business['postal_code'].isin(la_rest_zips)]))
# Out:
# 13
# 0
# 0

# %%
yelp_business_alt = pd.read_json('/Users/EBled1/Springboard DS/Springboard/Capstone Two/Capstone Two/data/raw/yelp_dataset/yelp_academic_dataset_business.json', lines = True)

# %%
yelp_business_alt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160585 entries, 0 to 160584
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   160585 non-null  object
#  1   name          160585 non-null  object
#  2   address       160585 non-null  object
#  3   city          160585 non-null  object
#  4   state         160585 non-null  object
#  5   postal_code   160585 non-null  object
#  6   latitude      160585 non-null  float64
#  7   longitude     160585 non-null  float64
#  8   stars         160585 non-null  float64
#  9   review_count  160585 non-null  int64
#  10  is_open       160585 non-null  int64
#  11  attributes    145593 non-null  object
#  12  categories    160470 non-null  object
#  13  hours         133244 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 17.2+ MB

# %%
yelp_business_alt.state.value_counts()
# Out:
# MA     36012
# OR     25175
# TX     24485
# FL     21907
# GA     18090
# BC     17298
# OH     11258
# CO      3198
# WA      3121
# CA        13
# NH         4
# ON         2
# AZ         2
# VA         2
# NY         2
# KY         1
# WY         1
# NM         1
# IL         1
# NC         1
# KS         1
# DE         1
# WI         1
# ABE        1
# DC         1
# OK         1
# HI         1
# AL         1
# MI         1
# ME         1
# MN         1
# Name: state, dtype: int64

# %%
boston_inspections = pd.read_csv('/Users/EBled1/Springboard DS/Springboard/Capstone Two/Capstone Two/data/raw/boston_restaurant_inspections.csv')
# Out:
# /Users/EBled1/Springboard DS/Springboard/Capstone Two/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
boston_inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649427 entries, 0 to 649426
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   businessname  649427 non-null  object
#  1   dbaname       6177 non-null    object
#  2   legalowner    443958 non-null  object
#  3   namelast      649427 non-null  object
#  4   namefirst     649313 non-null  object
#  5   licenseno     649427 non-null  int64
#  6   issdttm       649427 non-null  object
#  7   expdttm       649427 non-null  object
#  8   licstatus     649427 non-null  object
#  9   licensecat    649427 non-null  object
#  10  descript      649427 non-null  object
#  11  result        649427 non-null  object
#  12  resultdttm    649427 non-null  object
#  13  violation     613479 non-null  object
#  14  viollevel     613479 non-null  object
#  15  violdesc      611759 non-null  object
#  16  violdttm      649427 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 500)

# %%
boston_inspections.head(30)
# Out:
#                 businessname dbaname         legalowner namelast namefirst  \
# 0   100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 1   100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 2   100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 3   100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 4   100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 5   100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 6   100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 7   100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 8   100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 9   100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 10  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# ...

# %%
boston_inspections.violstatus.value_counts(normalize=True)
# Out:
# Fail    0.549949
# Pass    0.440703
#         0.009348
# Name: violstatus, dtype: float64

# %%
boston_inspections.result.value_counts(normalize=True)
# Out:
# HE_Fail       0.424274
# HE_Pass       0.314759
# HE_Filed      0.120551
# HE_FailExt    0.073097
# HE_Hearing    0.033255
# HE_NotReq     0.015860
# HE_TSOP       0.010723
# HE_OutBus     0.003437
# Pass          0.001486
# HE_Closure    0.000972
# HE_VolClos    0.000727
# Fail          0.000366
# HE_FAILNOR    0.000206
# HE_Misc       0.000180
# DATAERR       0.000065
# HE_Hold       0.000026
# Failed        0.000009
# PassViol      0.000003
# Closed        0.000003
# Name: result, dtype: float64

# %%
boston_inspections.viollevel.value_counts(normalize=True)
# Out:
# *       0.742187
# ***     0.169173
# **      0.085835
# -       0.002802
#         0.000002
# 1919    0.000002
# Name: viollevel, dtype: float64

# %%
boston_inspections['result'].loc[boston_inspections.violstatus == 'Pass'].value_counts(normalize=True)
# Out:
# HE_Pass       0.667553
# HE_Filed      0.169306
# HE_FailExt    0.110533
# HE_Hearing    0.035353
# HE_Fail       0.012272
# HE_TSOP       0.001520
# Pass          0.001483
# HE_OutBus     0.001102
# HE_FAILNOR    0.000314
# HE_NotReq     0.000263
# HE_Closure    0.000133
# HE_VolClos    0.000126
# Fail          0.000022
# HE_Misc       0.000015
# HE_Hold       0.000004
# Name: result, dtype: float64

# %%
cols = ['businessname','licenseno','resultdttm','zip','address','licstatus','violstatus']
#group_cols = ['businessname','licenseno','statusdate','zip','address','licstatus']
print(boston_inspections[cols].shape)
boston_inspections_trimmed = pd.DataFrame(boston_inspections[cols]).drop_duplicates().sort_values(by = ['businessname','address','resultdttm']).reset_index(drop=True)
print(boston_inspections_trimmed.shape)
boston_inspections_trimmed.head(30)
# Out:
# (649427, 7)
# (159778, 7)
#                 businessname  licenseno           resultdttm    zip  \
# 0   100 Percent Delicia Food      87059  2013-02-15 12:19:42  02131
# 1   100 Percent Delicia Food      87059  2013-02-20 12:33:09  02131
# 2   100 Percent Delicia Food      87059  2013-02-20 12:33:09  02131
# 3   100 Percent Delicia Food      87059  2013-03-21 14:48:33  02131
# 4   100 Percent Delicia Food      87059  2013-03-28 15:12:05  02131
# 5   100 Percent Delicia Food      87059  2013-04-02 12:10:43  02131
# 6   100 Percent Delicia Food      87059  2013-10-24 11:18:12  02131
# 7   100 Percent Delicia Food      87059  2013-10-31 14:30:04  02131
# 8   100 Percent Delicia Food      87059  2013-10-31 14:34:23  02131
# 9   100 Percent Delicia Food      87059  2013-10-31 14:34:23  02131
# 10  100 Percent Delicia Food      87059  2013-11-07 13:48:01  02131
# 11  100 Percent Delicia Food      87059  2014-03-06 13:32:36  02131
# ...

# %%
#boston_inspections_trimmed.violstatus.value_counts(normalize=True)
(boston_inspections_trimmed.loc[boston_inspections_trimmed.resultdttm.isna()==False]).violstatus.value_counts(normalize=True)
# Out:
# Fail    0.581012
# Pass    0.412061
#         0.006927
# Name: violstatus, dtype: float64

# %%
boston_inspections.loc[boston_inspections.statusdate.isna()==True]
# Out:
#                     businessname dbaname         legalowner namelast  \
# 0       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 1       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 2       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 3       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 4       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# ...                          ...     ...                ...      ...
# 649384       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 649385       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 649413       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 649414       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 649415       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
#
#        namefirst  licenseno              issdttm              expdttm  \
# ...

# %%
print(yelp_business_alt.columns)
yelp_business_alt.categories.unique().tolist()
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')
# ['Gastropubs, Food, Beer Gardens, Restaurants, Bars, American (Traditional), Beer Bar, Nightlife, Breweries',
#  'Salad, Soup, Sandwiches, Delis, Restaurants, Cafes, Vegetarian',
#  'Antiques, Fashion, Used, Vintage & Consignment, Shopping, Furniture Stores, Home & Garden',
#  'Beauty & Spas, Hair Salons',
#  'Gyms, Active Life, Interval Training Gyms, Fitness & Instruction',
#  'Restaurants, Thai',
#  'Dentists, Health & Medical, Orthodontists',
#  'Breakfast & Brunch, Restaurants',
#  'Shopping, Jewelry Repair, Appraisal Services, Local Services, Jewelry, Engraving, Gold Buyers',
#  'Barbers, Beauty & Spas',
#  'Food, Shopping, Convenience Stores, Souvenir Shops',
#  'Wigs, Hair Extensions, Hair Salons, Blow Dry/Out Services, Hair Stylists, Beauty & Spas, Shopping',
# ...

# %%
yelp_business_alt.loc[(yelp_business_alt.state == 'MA') & (yelp_business_alt['categories'].str.contains('Restaurants'))].sort_values(by=['name'])
# Out:
#                    business_id                              name  \
# 9082    r8yr6a2fB0qRyR5JOsxhQQ           &pizza - Harvard Square
# 138289  NGgfeJU0YE1SIodMserX1w                 'O' Yummy Cuisine
# 55303   BdHONnZzNFUdwQJbpuOd_A                     100% Delicias
# 3245    dAolyz6VhWLFnpltqOWp1w             100% Delicias Express
# 50944   _LLIO1lyRW2pu8q_AkUo5g  1000 Degrees Neapolitan Pizzeria
# ...                        ...                               ...
# 115793  hKQsbxqTWumRK8OPk3uoEQ                          wagamama
# 36717   rFC6p4oql9gzz2fScWKmGA                          wagamama
# 72621   X1qssn-paNYHiyjSxZ-VFg           wagamama - faneuil hall
# 47872   v95lM5eqV1feLxQakFN5bA             wagamama - prudential
# 17938   toy4tLf2J6-ti6JEwNrKZw                wagamama - seaport
#
#                   address           city state postal_code   latitude  \
# 9082         3 Brattle St      Cambridge    MA       02138  42.373574
# ...

# %%
cols2 = ['businessname','licenseno','zip','violstatus']
group_cols2 = ['businessname','licenseno','zip']

boston_inspections_trimmed2 = pd.DataFrame(boston_inspections[cols2]).drop_duplicates().sort_values(by = ['businessname','zip']).reset_index(drop=True)
print(boston_inspections_trimmed2.shape)
boston_inspections_trimmed2 = boston_inspections_trimmed2.dropna()
print(boston_inspections_trimmed2.shape)
boston_inspections_trimmed2.head(30)
# Out:
# (23563, 4)
# (15141, 4)
#                                       businessname  licenseno    zip  \
# 0                         100 Percent Delicia Food      87059  02131
# 1                         100 Percent Delicia Food      87059  02131
# 3                     100 Percent Delicias Express     351943  02130
# 5                     100 Percent Delicias Express     351943  02130
# 6                               1000 Degrees Pizza     313440  02108
# 8                               1000 Degrees Pizza     313440  02108
# 9                             1000 Washington Cafe      34789  02118
# 11                            1000 Washington Cafe      34789  02118
# 12                             11 Dining -16th Fl.     418637  02116
# 13                                       110 Grill     381384  02125
# 15                                       110 Grill     381384  02125
# 17                       125 Nashua St. Cafe (MGH)     130844  02114
# ...

# %%
# move this to appropriate function in cookiecutter
# and call function from there

def column_value_flag(row):
    if row['violstatus'] == 'Fail':
        return 1
    return 0

# %%
boston_inspections_trimmed2['fail_flag'] = boston_inspections_trimmed2.apply (lambda row: column_value_flag(row), axis=1)
boston_inspections_trimmed2.head()
# Out:
#                    businessname  licenseno    zip violstatus  fail_flag
# 0      100 Percent Delicia Food      87059  02131       Fail          1
# 1      100 Percent Delicia Food      87059  02131       Pass          0
# 3  100 Percent Delicias Express     351943  02130       Fail          1
# 5  100 Percent Delicias Express     351943  02130       Pass          0
# 6            1000 Degrees Pizza     313440  02108       Fail          1

# %%
del boston_inspections_trimmed2['violstatus']
boston_inspections_trimmed2.groupby(by=['businessname','licenseno','zip']).sum()
# Out:
#                                               fail_flag
# businessname                 licenseno zip
# 100 Percent Delicia Food     87059     02131          1
# 100 Percent Delicias Express 351943    02130          1
# 1000 Degrees Pizza           313440    02108          1
# 1000 Washington Cafe         34789     02118          1
# 11 Dining -16th Fl.          418637    02116          1
# ...                                                 ...
# eat @ Corner Cafe            28271     02118          1
# i Scream Works               29847     02132          1
# iFresh Noodle                407682    02134          1
# sultana's bakery & cafe      156835    02135          1
# the dorset                   156560    2122           1
#
# [7607 rows x 1 columns]

# %%
boston_inspections_trimmed3 = boston_inspections_trimmed2.groupby(by=['businessname','licenseno','zip']).sum().reset_index()
boston_inspections_trimmed3.head()
# Out:
#                    businessname  licenseno    zip  fail_flag
# 0      100 Percent Delicia Food      87059  02131          1
# 1  100 Percent Delicias Express     351943  02130          1
# 2            1000 Degrees Pizza     313440  02108          1
# 3          1000 Washington Cafe      34789  02118          1
# 4           11 Dining -16th Fl.     418637  02116          1

# %%
boston_inspections_trimmed3.fail_flag.value_counts(normalize=True)
# Out:
# 1    0.98922
# 0    0.01078
# Name: fail_flag, dtype: float64

# %%
violations = pd.read_csv('/Users/EBled1/Springboard DS/Springboard/Capstone Two/Capstone Two/data/raw/violations.csv')

# %%
violations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 906014 entries, 0 to 906013
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   points                 906014 non-null  int64
#  1   serial_number          906014 non-null  object
#  2   violation_code         906014 non-null  object
#  3   violation_description  906014 non-null  object
#  4   violation_status       906014 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 34.6+ MB

# %%
group pass/fail by year/season (depending on data) to look at imbalance
join yelp data to boston
send agenda to Branko

--separately break out time series later on

# %%
dallas_inspections = pd.read_csv('/Users/EBled1/Springboard DS/Springboard/Capstone Two/Capstone Two/data/raw/dallas_restaurant_inspections.csv')
# Out:
# /Users/EBled1/Springboard DS/Springboard/Capstone Two/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (10,107,109,110) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dallas_inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54081 entries, 0 to 54080
# Columns: 114 entries, Restaurant Name to Lat Long Location
# dtypes: float64(25), int64(2), object(87)
# memory usage: 47.0+ MB

# %%
dallas_inspections.head()
# Out:
#                    Restaurant Name Inspection Type Inspection Date  \
# 0                   MICKLE CHICKEN         Routine      10/30/2019
# 1            TOM THUMB - JUICE BAR         Routine      04/08/2020
# 2             BROOKDALE WHITE ROCK         Routine      07/29/2020
# 3            CHURCH'S CHICKEN #201         Routine      09/14/2020
# 4  PEAK PREPARATORY-PRIMARY SCHOOL         Routine      04/25/2017
#
#    Inspection Score  Street Number  Street Name Street Direction Street Type  \
# 0               100           3203  CAMP WISDOM                W          RD
# 1               100           2380        FIELD                N          ST
# 2                97           9271   WHITE ROCK              NaN         TRL
# 3               100          10295     FERGUSON              NaN          RD
# 4                98           1474        ANNEX              NaN         AVE
#
#   Street Unit         Street Address Zip Code Violation Description - 1  \
# ...

# %%
dallas_inspections['Inspection Score'].value_counts(normalize=True).sort_values(ascending = False)
# Out:
# 100    0.078198
# 97     0.065531
# 95     0.059318
# 94     0.058782
# 96     0.057469
# 90     0.056600
# 92     0.054215
# 80     0.054178
# 93     0.053087
# 91     0.051589
# 98     0.048021
# 88     0.041253
# 89     0.039552
# 99     0.038220
# 87     0.035743
# 86     0.033727
# 85     0.032359
# 84     0.027496
# 81     0.024445
# 83     0.024112
# 82     0.023631
# 70     0.005751
# 76     0.003976
# 75     0.003791
# 74     0.003569
# 72     0.003513
# 77     0.003458
# 73     0.003162
# 78     0.003088
# 71     0.002681
# 79     0.002126
# 69     0.001054
# 66     0.000980
# 68     0.000869
# 64     0.000758
# 67     0.000666
# 65     0.000666
# 63     0.000536
# 60     0.000499
# 62     0.000462
# 61     0.000444
# 57     0.000092
# 59     0.000074
# 58     0.000055
# 0      0.000037
# 54     0.000037
# 51     0.000037
# 56     0.000018
# 55     0.000018
# 53     0.000018
# 52     0.000018
# 50     0.000018
# Name: Inspection Score, dtype: float64

# %%
# move this to appropriate function in cookiecutter
# and call function from there

def letter_grade(row):
    if row['Inspection Score'] >= 90:
        return 'A'
    if row['Inspection Score'] >= 80:
        return 'B'
    if row['Inspection Score'] >= 70:
        return 'C'
    return 'F'

# %%
dallas_inspections['letter_grade'] = dallas_inspections.apply (lambda row: letter_grade(row), axis=1)
dallas_inspections.sort_values(by=['Restaurant Name']).head(30)
# Out:
#                     Restaurant Name Inspection Type Inspection Date  \
# 10726              "LET'S DO LUNCH"         Routine      02/24/2020
# 38412              "LET'S DO LUNCH"         Routine      08/30/2018
# 24571              "LET'S DO LUNCH"         Routine      02/08/2017
# 35251              "LET'S DO LUNCH"         Routine      02/09/2018
# 2042               "LET'S DO LUNCH"         Routine      08/28/2019
# 32920              "LET'S DO LUNCH"         Routine      08/14/2017
# 23910              "LET'S DO LUNCH"         Routine      02/15/2019
# 50953  #1 CHAMPION BILLIARD & GAMES         Routine      02/18/2019
# 51098  #1 CHAMPION BILLIARD & GAMES         Routine      03/31/2017
# 51095  #1 CHAMPION BILLIARD & GAMES         Routine      01/19/2018
# 50318  #1 CHAMPION BILLIARD & GAMES         Routine      07/29/2018
# 26860                $ STUFF & MORE         Routine      12/30/2016
# 26792                $ STUFF & MORE         Routine      12/12/2017
# ...

# %%
dallas_inspections.letter_grade.value_counts(normalize=True)
# Out:
# A    0.621031
# B    0.336495
# C    0.035114
# F    0.007359
# Name: letter_grade, dtype: float64

# %%
print(yelp_business_alt.columns)
yelp_business_alt.categories.unique().tolist()
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')
# ['Gastropubs, Food, Beer Gardens, Restaurants, Bars, American (Traditional), Beer Bar, Nightlife, Breweries',
#  'Salad, Soup, Sandwiches, Delis, Restaurants, Cafes, Vegetarian',
#  'Antiques, Fashion, Used, Vintage & Consignment, Shopping, Furniture Stores, Home & Garden',
#  'Beauty & Spas, Hair Salons',
#  'Gyms, Active Life, Interval Training Gyms, Fitness & Instruction',
#  'Restaurants, Thai',
#  'Dentists, Health & Medical, Orthodontists',
#  'Breakfast & Brunch, Restaurants',
#  'Shopping, Jewelry Repair, Appraisal Services, Local Services, Jewelry, Engraving, Gold Buyers',
#  'Barbers, Beauty & Spas',
#  'Food, Shopping, Convenience Stores, Souvenir Shops',
#  'Wigs, Hair Extensions, Hair Salons, Blow Dry/Out Services, Hair Stylists, Beauty & Spas, Shopping',
# ...

# %%
yelp_tx = yelp_business_alt.loc[(yelp_business_alt.state == 'TX') & (yelp_business_alt['categories'].str.contains('Restaurants'))].sort_values(by=['name'])
yelp_tx.address = yelp_tx.address.str.upper()
yelp_tx.head()
# Out:
#                    business_id                              name  \
# 77606   sS25ybHXWdkdhcUhfkWJxQ                              # 19
# 56196   248ccWwT6bFbR6am5w391A                      100 Pizzitas
# 56947   G50RJhfZgaVqnKEWrjD_Aw  1000 Degrees Neapolitan Pizzeria
# 60724   6uSPLo9R0vxtJxPIhsMSMg                    101 By Teahaus
# 159663  a4RvgJWV2wd2DeogFE85_w               11th Street Station
#
#                              address    city state postal_code   latitude  \
# 77606                  1112 E 6TH ST  Austin    TX       78702  30.264840
# 56196                   900 E 7TH ST  Austin    TX       78702  30.266555
# 56947   10515 N MOPAC EXPY, STE A120  Austin    TX       78757  30.389495
# 60724     6929 AIRPORT BLVD, STE 132  Austin    TX       78752  30.337121
# 159663       1050 E 11TH ST, STE 100  Austin    TX       78702  30.269190
#
#         longitude  stars  review_count  is_open  \
# 77606  -97.730867    4.5            18        0
# ...

# %%
#join yelp data
print(dallas_inspections.shape)
dallas_inspections_yelp = dallas_inspections.merge(yelp_tx, how='left', left_on ='Street Address', right_on ='address',
                        suffixes = ('','_yelp'))
print(dallas_inspections_yelp.shape)
# Out:
# (54081, 115)
# (54081, 129)

# %%
dallas_inspections_yelp.head()
# Out:
#                    Restaurant Name Inspection Type Inspection Date  \
# 0                   MICKLE CHICKEN         Routine      10/30/2019
# 1            TOM THUMB - JUICE BAR         Routine      04/08/2020
# 2             BROOKDALE WHITE ROCK         Routine      07/29/2020
# 3            CHURCH'S CHICKEN #201         Routine      09/14/2020
# 4  PEAK PREPARATORY-PRIMARY SCHOOL         Routine      04/25/2017
#
#    Inspection Score  Street Number  Street Name Street Direction Street Type  \
# 0               100           3203  CAMP WISDOM                W          RD
# 1               100           2380        FIELD                N          ST
# 2                97           9271   WHITE ROCK              NaN         TRL
# 3               100          10295     FERGUSON              NaN          RD
# 4                98           1474        ANNEX              NaN         AVE
#
#   Street Unit         Street Address Zip Code Violation Description - 1  \
# ...

# %%
dallas_inspections_yelp.loc[dallas_inspections_yelp.business_id.isna()==False]
# Out:
# Empty DataFrame
# ...

# %%
yelp_tx.city.unique()
# Out:
# array(['Austin', 'Lakeway', 'Rollingwood', 'AUSTIN', 'Dripping Springs',
#        'Buda', 'Pflugerville', 'Manor', 'Bee Cave', 'Kyle',
#        'Sunset Valley', 'West Lake Hills', 'Manchaca', 'Leander',
#        'Del Valle', 'Bee Caves', 'Niederwald', 'Driftwood', 'Garfield',
#        'Spicewood', 'Jackson', 'Thoroughbred Estates', 'Oakhill',
#        'Pilot Knob Acres', 'North Lamar', 'Volente', 'Lago Vista',
#        'Austin texas', 'Dallas', 'Point Venture', 'San Marcos',
#        'Creedmoor', 'Beecave'], dtype=object)

# %%
dallas_inspections['Lat Long Location']
# Out:
# 0           3203 W CAMP WISDOM RD\n(32.662584, -96.873446)
# 1                  2380 N FIELD ST\n(32.78904, -96.806882)
# 2             9271 WHITE ROCK TRL\n(32.872855, -96.728807)
# 3                10295 FERGUSON RD\n(32.83427, -96.673672)
# 4                     1474 ANNEX AVE\n(32.80208, -96.7769)
#                                ...
# 54076    10455 N CENTRAL EXPW #120\n(32.888793, -96.77012)
# 54077             3308 W DAVIS ST\n(32.749482, -96.874487)
# 54078             6324 GASTON AVE\n(32.813079, -96.753686)
# 54079            4849 W LAWTHER DR\n(32.85442, -96.730528)
# 54080           17552 DALLAS PKWY\n(32.990131, -96.828758)
# Name: Lat Long Location, Length: 54081, dtype: object

# %%
dallas_inspections['latitude'] = (dallas_inspections['Lat Long Location'].str.split('(').str[1]).str.split(',').str[0]
dallas_inspections.head()
# Out:
#                    Restaurant Name Inspection Type Inspection Date  \
# 0                   MICKLE CHICKEN         Routine      10/30/2019
# 1            TOM THUMB - JUICE BAR         Routine      04/08/2020
# 2             BROOKDALE WHITE ROCK         Routine      07/29/2020
# 3            CHURCH'S CHICKEN #201         Routine      09/14/2020
# 4  PEAK PREPARATORY-PRIMARY SCHOOL         Routine      04/25/2017
#
#    Inspection Score  Street Number  Street Name Street Direction Street Type  \
# 0               100           3203  CAMP WISDOM                W          RD
# 1               100           2380        FIELD                N          ST
# 2                97           9271   WHITE ROCK              NaN         TRL
# 3               100          10295     FERGUSON              NaN          RD
# 4                98           1474        ANNEX              NaN         AVE
#
#   Street Unit         Street Address Zip Code Violation Description - 1  \
# ...

# %%
dallas_inspections['longitude'] = ((dallas_inspections['Lat Long Location'].str.split('(').str[1]).str.split(',').str[1]).str.split(')').str[0]
dallas_inspections.head()
# Out:
#                    Restaurant Name Inspection Type Inspection Date  \
# 0                   MICKLE CHICKEN         Routine      10/30/2019
# 1            TOM THUMB - JUICE BAR         Routine      04/08/2020
# 2             BROOKDALE WHITE ROCK         Routine      07/29/2020
# 3            CHURCH'S CHICKEN #201         Routine      09/14/2020
# 4  PEAK PREPARATORY-PRIMARY SCHOOL         Routine      04/25/2017
#
#    Inspection Score  Street Number  Street Name Street Direction Street Type  \
# 0               100           3203  CAMP WISDOM                W          RD
# 1               100           2380        FIELD                N          ST
# 2                97           9271   WHITE ROCK              NaN         TRL
# 3               100          10295     FERGUSON              NaN          RD
# 4                98           1474        ANNEX              NaN         AVE
#
#   Street Unit         Street Address Zip Code Violation Description - 1  \
# ...

# %%
yelp_tx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5444 entries, 77606 to 42299
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   5444 non-null   object
#  1   name          5444 non-null   object
#  2   address       5444 non-null   object
#  3   city          5444 non-null   object
#  4   state         5444 non-null   object
#  5   postal_code   5444 non-null   object
#  6   latitude      5444 non-null   float64
#  7   longitude     5444 non-null   float64
#  8   stars         5444 non-null   float64
#  9   review_count  5444 non-null   int64
#  10  is_open       5444 non-null   int64
#  11  attributes    5393 non-null   object
#  12  categories    5444 non-null   object
#  13  hours         4664 non-null   object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 638.0+ KB

# %%
yelp_tx.latitude = str(yelp_tx.latitude)
yelp_tx.longitude = str(yelp_tx.longitude)
yelp_tx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5444 entries, 77606 to 42299
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   5444 non-null   object
#  1   name          5444 non-null   object
#  2   address       5444 non-null   object
#  3   city          5444 non-null   object
#  4   state         5444 non-null   object
#  5   postal_code   5444 non-null   object
#  6   latitude      5444 non-null   object
#  7   longitude     5444 non-null   object
#  8   stars         5444 non-null   float64
#  9   review_count  5444 non-null   int64
#  10  is_open       5444 non-null   int64
#  11  attributes    5393 non-null   object
#  12  categories    5444 non-null   object
#  13  hours         4664 non-null   object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 638.0+ KB

# %%
#join yelp data
print(dallas_inspections.shape)
dallas_inspections_yelp2 = dallas_inspections.merge(yelp_tx, how='left', on =['latitude','longitude'],
                        suffixes = ('','_yelp'))
print(dallas_inspections_yelp2.shape)
# Out:
# (54081, 117)
# (54081, 129)

# %%
dallas_inspections_yelp2.loc[dallas_inspections_yelp2.business_id.isna()==True]
# Out:
#                        Restaurant Name Inspection Type Inspection Date  \
# 0                       MICKLE CHICKEN         Routine      10/30/2019
# 1                TOM THUMB - JUICE BAR         Routine      04/08/2020
# 2                 BROOKDALE WHITE ROCK         Routine      07/29/2020
# 3                CHURCH'S CHICKEN #201         Routine      09/14/2020
# 4      PEAK PREPARATORY-PRIMARY SCHOOL         Routine      04/25/2017
# ...                                ...             ...             ...
# 54076      TAJ MAHAL INDIAN RESTAURANT         Routine      04/16/2019
# 54077                          POPEYES         Routine      04/23/2021
# 54078                CRAFT BEER CELLAR         Routine      04/30/2021
# 54079          CC YOUNG (LEVEL 2 CAFE)         Routine      04/19/2021
# 54080             MAGUIRE'S RESTAURANT         Routine      05/03/2021
#
#        Inspection Score  Street Number  Street Name Street Direction  \
# ...

# %%
yelp_tx.loc[yelp_tx.postal_code.str.upper() == '75287']
# Out:
# Empty DataFrame
# Columns: [business_id, name, address, city, state, postal_code, latitude, longitude, stars, review_count, is_open, attributes, categories, hours]
# Index: []

# %%
yelp_tx.city.value_counts(normalize=True)
# Out:
# Austin                  0.910360
# Buda                    0.013042
# Bee Cave                0.012123
# Kyle                    0.011940
# Lakeway                 0.011389
# Dripping Springs        0.010287
# Manor                   0.006062
# Pflugerville            0.006062
# Sunset Valley           0.004225
# West Lake Hills         0.003857
# Del Valle               0.003123
# Manchaca                0.001653
# Driftwood               0.000735
# AUSTIN                  0.000551
# Spicewood               0.000367
# Leander                 0.000367
# Volente                 0.000367
# Bee Caves               0.000367
# Point Venture           0.000367
# Rollingwood             0.000367
# Lago Vista              0.000184
# Austin texas            0.000184
# Niederwald              0.000184
# Garfield                0.000184
# San Marcos              0.000184
# Creedmoor               0.000184
# Thoroughbred Estates    0.000184
# Oakhill                 0.000184
# ...

# %%
austin_inspections = pd.read_csv('/Users/EBled1/Springboard DS/Springboard/Capstone Two/Capstone Two/data/raw/austin_restaurant_inspections.csv')

# %%
austin_inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25393 entries, 0 to 25392
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Restaurant Name      25393 non-null  object
#  1   Zip Code             25385 non-null  float64
#  2   Inspection Date      25393 non-null  object
#  3   Score                25393 non-null  int64
#  4   Address              25391 non-null  object
#  5   Facility ID          25393 non-null  int64
#  6   Process Description  25393 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.4+ MB

# %%
austin_inspections.head()
# Out:
#                    Restaurant Name  Zip Code Inspection Date  Score  \
# 0                 Austin Golf Club   78669.0      08/15/2018    100
# 1         Habesha Restaurant & Bar   78723.0      02/12/2018     78
# 2  LW - Raising Cane's Restaurants   78734.0      09/15/2020    100
# 3               Dollar Tree #07241   78736.0      01/25/2018     92
# 4   Cedar International Academy II   78753.0      05/09/2018     85
#
#                                Address  Facility ID Process Description
# 0      24900 W SH\nSPICEWOOD, TX 78669      2801719  Routine Inspection
# 1                1 2\nAUSTIN, TX 78723     10864575  Routine Inspection
# 2  1600 S FM 620 RD\nLAKEWAY, TX 78734     11531765  Routine Inspection
# 3          7101 W SH\nAUSTIN, TX 78736     11723124  Routine Inspection
# 4          8416 N IH\nAUSTIN, TX 78753     10118311  Routine Inspection

# %%
austin_inspections.sort_values(by=['Restaurant Name','Inspection Date']).head(30)
# Out:
#               Restaurant Name  Zip Code Inspection Date  Score  \
# 2362                      "CB   78701.0      01/02/2020     96
# 17494                     "CB   78701.0      03/08/2018     99
# 23397                     "CB   78701.0      08/05/2019     95
# 11497                     "CB   78701.0      09/05/2018     95
# 6705                      "CB   78701.0      11/17/2020     97
# 17165           'Bout Time II   78752.0      03/02/2020     83
# 19              'Bout Time II   78752.0      06/05/2018     83
# 9538            'Bout Time II   78752.0      07/25/2019     77
# 7528        1-Stop Food Store   78751.0      06/27/2018     94
# 15141       1-Stop Food Store   78751.0      12/05/2018     93
# 21079       1-Stop Food Store   78751.0      12/12/2019     96
# 24084       1-Stop Food Store   78751.0      12/16/2020     97
# 16354     101 by Tea Haus LLC   78752.0      01/07/2020     94
# 2882      101 by Tea Haus LLC   78752.0      04/30/2019     93
# ...

# %%
# move this to appropriate function in cookiecutter
# and call function from there

def letter_grade(row):
    if row['Score'] >= 90:
        return 'A'
    if row['Score'] >= 80:
        return 'B'
    if row['Score'] >= 70:
        return 'C'
    return 'F'

# %%
austin_inspections['letter_grade'] = austin_inspections.apply (lambda row: letter_grade(row), axis=1)
austin_inspections.sort_values(by=['Restaurant Name']).head(30)
# Out:
#               Restaurant Name  Zip Code Inspection Date  Score  \
# 11497                     "CB   78701.0      09/05/2018     95
# 6705                      "CB   78701.0      11/17/2020     97
# 23397                     "CB   78701.0      08/05/2019     95
# 17494                     "CB   78701.0      03/08/2018     99
# 2362                      "CB   78701.0      01/02/2020     96
# 17165           'Bout Time II   78752.0      03/02/2020     83
# 9538            'Bout Time II   78752.0      07/25/2019     77
# 19              'Bout Time II   78752.0      06/05/2018     83
# 21079       1-Stop Food Store   78751.0      12/12/2019     96
# 7528        1-Stop Food Store   78751.0      06/27/2018     94
# 24084       1-Stop Food Store   78751.0      12/16/2020     97
# 15141       1-Stop Food Store   78751.0      12/05/2018     93
# 20773     101 by Tea Haus LLC   78752.0      10/24/2018     87
# 10360     101 by Tea Haus LLC   78752.0      08/15/2019     96
# ...

# %%
austin_inspections.letter_grade.value_counts(normalize=True)
# Out:
# A    0.696176
# B    0.239909
# C    0.058638
# F    0.005277
# Name: letter_grade, dtype: float64

# %%
austin_inspections.Address
# Out:
# 0                          24900 W SH\nSPICEWOOD, TX 78669
# 1                                    1 2\nAUSTIN, TX 78723
# 2                      1600 S FM 620 RD\nLAKEWAY, TX 78734
# 3                              7101 W SH\nAUSTIN, TX 78736
# 4                              8416 N IH\nAUSTIN, TX 78753
#                                ...
# 25388    5701 W SLAUGHTER LN\nAUSTIN, TX 78749\n(30.201...
# 25389    5313 MANOR RD\nAUSTIN, TX 78723\n(30.300732, -...
# 25390    13717 BURNET RD\nAUSTIN, TX 78727\n(30.438049,...
# 25391    5222 BURNET RD\nAUSTIN, TX 78756\n(30.324549, ...
# 25392    2408 S US 183 HWY\nAUSTIN, TX 78744\n(30.21294...
# Name: Address, Length: 25393, dtype: object

# %%
austin_inspections['addr_line_1'] = (austin_inspections['Address'].str.split('\n').str[0].str.upper())
austin_inspections.head()
# Out:
#                    Restaurant Name  Zip Code Inspection Date  Score  \
# 0                 Austin Golf Club     78669      08/15/2018    100
# 1         Habesha Restaurant & Bar     78723      02/12/2018     78
# 2  LW - Raising Cane's Restaurants     78734      09/15/2020    100
# 3               Dollar Tree #07241     78736      01/25/2018     92
# 4   Cedar International Academy II     78753      05/09/2018     85
#
#                                Address  Facility ID Process Description  \
# 0      24900 W SH\nSPICEWOOD, TX 78669      2801719  Routine Inspection
# 1                1 2\nAUSTIN, TX 78723     10864575  Routine Inspection
# 2  1600 S FM 620 RD\nLAKEWAY, TX 78734     11531765  Routine Inspection
# 3          7101 W SH\nAUSTIN, TX 78736     11723124  Routine Inspection
# 4          8416 N IH\nAUSTIN, TX 78753     10118311  Routine Inspection
#
#   letter_grade       addr_line_1
# 0            A        24900 W SH
# 1            C               1 2
# ...

# %%
austin_inspections['Zip Code'] = austin_inspections['Zip Code'].apply(str)

# %%
austin_inspections.head()
# Out:
#                    Restaurant Name Zip Code Inspection Date  Score  \
# 0                 Austin Golf Club    78669      08/15/2018    100
# 1         Habesha Restaurant & Bar    78723      02/12/2018     78
# 2  LW - Raising Cane's Restaurants    78734      09/15/2020    100
# 3               Dollar Tree #07241    78736      01/25/2018     92
# 4   Cedar International Academy II    78753      05/09/2018     85
#
#                                Address  Facility ID Process Description  \
# 0      24900 W SH\nSPICEWOOD, TX 78669      2801719  Routine Inspection
# 1                1 2\nAUSTIN, TX 78723     10864575  Routine Inspection
# 2  1600 S FM 620 RD\nLAKEWAY, TX 78734     11531765  Routine Inspection
# 3          7101 W SH\nAUSTIN, TX 78736     11723124  Routine Inspection
# 4          8416 N IH\nAUSTIN, TX 78753     10118311  Routine Inspection
#
#   letter_grade       addr_line_1
# 0            A        24900 W SH
# 1            C               1 2
# ...

# %%
austin_inspections['Zip Code']
austin_inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25393 entries, 0 to 25392
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Restaurant Name      25393 non-null  object
#  1   Zip Code             25393 non-null  object
#  2   Inspection Date      25393 non-null  object
#  3   Score                25393 non-null  int64
#  4   Address              25391 non-null  object
#  5   Facility ID          25393 non-null  int64
#  6   Process Description  25393 non-null  object
#  7   letter_grade         25393 non-null  object
#  8   addr_line_1          25391 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 1.7+ MB

# %%
yelp_tx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5444 entries, 77606 to 42299
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   5444 non-null   object
#  1   name          5444 non-null   object
#  2   address       5444 non-null   object
#  3   city          5444 non-null   object
#  4   state         5444 non-null   object
#  5   postal_code   5444 non-null   object
#  6   latitude      5444 non-null   object
#  7   longitude     5444 non-null   object
#  8   stars         5444 non-null   float64
#  9   review_count  5444 non-null   int64
#  10  is_open       5444 non-null   int64
#  11  attributes    5393 non-null   object
#  12  categories    5444 non-null   object
#  13  hours         4664 non-null   object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 638.0+ KB

# %%
austin_inspections['Restaurant Name'] = austin_inspections['Restaurant Name'].str.upper()
yelp_tx['name'] = yelp_tx['name'].str.upper()

# %%
#join yelp data
print(austin_inspections.shape)
austin_inspections_yelp = austin_inspections.merge(yelp_tx, how='left', left_on =['addr_line_1','Zip Code'], right_on =['address','postal_code'],
                        suffixes = ('','_yelp'))
print(austin_inspections_yelp.shape)
# Out:
# (25393, 9)
# (35417, 23)

# %%
pd.set_option('display.max_rows',500)
print(len(austin_inspections_yelp))
print(len(austin_inspections_yelp.loc[austin_inspections_yelp.business_id.isna()==True]))
austin_inspections_yelp[['Restaurant Name','name']].loc[austin_inspections_yelp.business_id.isna()==False].head(100)
# Out:
# 35417
# 15397
#                             Restaurant Name  \
# 25                FRESA'S CHICKEN AL CARBON
# 27                     OOB-ABIA - VINO VOLO
# 28                     OOB-ABIA - VINO VOLO
# 29                     OOB-ABIA - VINO VOLO
# 30                     OOB-ABIA - VINO VOLO
# 31                     OOB-ABIA - VINO VOLO
# 32                     OOB-ABIA - VINO VOLO
# 33                     OOB-ABIA - VINO VOLO
# 34                     OOB-ABIA - VINO VOLO
# 35                     OOB-ABIA - VINO VOLO
# 36                     OOB-ABIA - VINO VOLO
# 37                     OOB-ABIA - VINO VOLO
# 38                     OOB-ABIA - VINO VOLO
# 39                     OOB-ABIA - VINO VOLO
# 40                     OOB-ABIA - VINO VOLO
# 44                         WHATABURGER #346
# 50                  ROARING FORK RESTAURANT
# 51                  ROARING FORK RESTAURANT
# 52                       LONE STAR KOLACHES
# 53                       LONE STAR KOLACHES
# ...

# %%
austin_inspections['Zip Code']
# Out:
# 0        78669
# 1        78723
# 2        78734
# 3        78736
# 4        78753
#          ...
# 25388    78749
# 25389    78723
# 25390    78727
# 25391    78756
# 25392    78744
# Name: Zip Code, Length: 25393, dtype: object

# %%
> add lat/long to join criteria
> fuzzy match on restaurant name
